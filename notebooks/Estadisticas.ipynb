# %% [markdown]
# # Tarea repositorio en github
# Miguel Ruiz Benavides

# %% [markdown]
# se reproduce notebook en un repositorio en github https://github.com/miguel5458-creator/Test_taxis?tab=readme-ov-file

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Analisis estadistico

# %% [markdown]
# ## Importación de variables

# %%
import pandas as pd



taxi_feb = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-02.parquet')
taxi_may= pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-04.parquet')

# %% [markdown]
# ## Test de hipotesis

# %% [markdown]
# H0: Las medias de las variables numéricas de los dos grupos son iguales.
#
# H1: Las medias de las variables numéricas de los dos grupos son diferentes.

# %%
import pandas as pd
from scipy.stats import ttest_ind


def test(fecha1,fecha2):

    numeric_df_feb = taxi_feb.select_dtypes(include='number')
    numeric_df_may = taxi_may.select_dtypes(include='number')

    for variable in numeric_df_feb.columns:
        if variable in numeric_df_may.columns:
         
            data_feb = numeric_df_feb[variable].dropna()
            data_may = numeric_df_may[variable].dropna()

            t_stat, p_value = ttest_ind(data_feb, data_may)



            if p_value < 0.05:
                print(f"Rechazamos la hipótesis nula para la variable o campo {variable} su p valor = {p_value} <0.05: Las medias son significativamente diferentes.")
            else:
                print(f"No rechazamos la hipótesis nula para la variable o campo {variable} su p valor = {p_value} >0.05: No hay evidencia suficiente para decir que las medias son diferentes.")
        else:
            print(f'La variable {variable} no se encuentra en ambos DataFrames.')

# %%
test(taxi_feb,taxi_may)
# Out:
# Rechazamos la hipótesis nula para la variable o campo VendorID su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo passenger_count su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo trip_distance su p valor = 2.56751112902721e-16 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo RatecodeID su p valor = 1.0427896655171654e-37 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo PULocationID su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo DOLocationID su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo payment_type su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo fare_amount su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo extra su p valor = 1.879711887502338e-56 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo mta_tax su p valor = 7.522607647950794e-302 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo tip_amount su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo tolls_amount su p valor = 2.4857602393069374e-206 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo improvement_surcharge su p valor = 5.064317680787965e-106 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo total_amount su p valor = 0.0 <0.05: Las medias son significativamente diferentes.
# Rechazamos la hipótesis nula para la variable o campo congestion_surcharge su p valor = 0.0 <0.05: Las medias son significativamente diferentes.

# %% [markdown]
# ## Estadistica descriptiva

# %%
desc_feb = taxi_feb.describe()
desc_may = taxi_may.describe()
desc_feb
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  6.299367e+06                     6299367                     6299367
# mean   1.673616e+00  2020-02-15 17:07:47.789266  2020-02-15 17:23:55.531851
# min    1.000000e+00         2008-12-31 22:20:23         2008-12-31 22:55:19
# 25%    1.000000e+00  2020-02-08 04:46:57.500000         2020-02-08 05:18:01
# 50%    2.000000e+00         2020-02-15 07:17:55         2020-02-15 07:39:47
# 75%    2.000000e+00         2020-02-22 23:46:54         2020-02-23 00:02:15
# max    6.000000e+00         2020-07-11 12:57:52         2020-07-11 12:59:24
# std    4.692367e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count
#
#         DOLocationID   payment_type    fare_amount          extra  \
# count  238073.000000  238073.000000  238073.000000  238073.000000
# mean      150.355660       1.308473      11.669133       1.067176
# min         1.000000       0.000000    -118.000000      -4.500000
# 25%        75.000000       1.000000       5.500000       0.000000
# 50%       143.000000       1.000000       8.000000       0.500000
# 75%       233.000000       2.000000      13.000000       2.500000
# max       265.000000       4.000000     903.020000       9.060000
# std        74.475937       0.661205      11.731917       1.260589
#
#              mta_tax     tip_amount   tolls_amount  improvement_surcharge  \
# count  238073.000000  238073.000000  238073.000000          238073.000000
# mean        0.486983       1.529937       0.220858               0.296319
# min        -0.500000      -5.000000     -19.870000              -0.300000
# 25%         0.500000       0.000000       0.000000               0.300000
# 50%         0.500000       1.000000       0.000000               0.300000
# 75%         0.500000       2.460000       0.000000               0.300000
# max         1.100000     117.280000      98.750000               0.300000
# std         0.095030       2.295454       1.343803               0.045462
#
#         total_amount  congestion_surcharge
# count  238073.000000         218493.000000
# mean       16.411970              2.023246
# min      -138.170000             -2.500000
# 25%         9.800000              2.500000
# 50%        12.800000              2.500000
# 75%        18.360000              2.500000
# max       903.320000              2.500000
# std        13.160379              1.008096

# %% [markdown]
# ## Visualizaciones

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
def plot_data(df, title):
    df = df.sample(10000)
    # Crear una instancia del escalador Min-Max
    scaler = MinMaxScaler()
    numeric_df = df.select_dtypes(include='number')

    # Ajustar y transformar el DataFrame
    numeric_df = pd.DataFrame(scaler.fit_transform(numeric_df), columns=numeric_df.columns)

    # Crear gráficos
    num_vars = numeric_df.columns
    n_vars = len(num_vars)
    
    # Determinar el tamaño de la figura en función del número de gráficos
    n_cols = 3  # Número de columnas en los subplots
    n_rows = (n_vars + n_cols - 1) // n_cols  # Calcular el número de filas necesarias

    plt.figure(figsize=(n_cols * 6, n_rows * 4))

    for i, var in enumerate(num_vars):
        plt.subplot(n_rows, n_cols, i + 1)
        sns.histplot(numeric_df[var], kde=True)
        plt.title(f'Histograma de {var}')
    
    plt.tight_layout()
    plt.suptitle(title, y=1.02)
    plt.show()

# Crear visualizaciones para ambos DataFrames
plot_data(taxi_feb, 'Datos de Febrero 2020')
plot_data(taxi_may, 'Datos de Abril 2020')

# %% [markdown]
# # Conclusión

# %% [markdown]
# Al observar la estadística descriptiva utilizando el método .describe(), se aprecian resultados diferentes. Esto se corrobora mediante histogramas, los cuales, debido a limitaciones de tiempo, se basaron en muestras. Estos histogramas muestran distribuciones distintas.
#
# Finalmente, mediante la inferencia estadística utilizando pruebas de hipótesis, se demostró que rechazamos la hipótesis nula para todas las variables numéricas, dado que el valor p es menor a 0.05. Esto indica que las medias son significativamente diferentes.
